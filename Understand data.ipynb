# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("India_housing_prices.csv")

# %%
df.head()
# Out:
#    Property_ID          State     City      Locality      Property_Type  BHK  \
# 0            1          Delhi    Delhi  Locality_130          Apartment    4
# 1            2  Uttar Pradesh  Lucknow  Locality_245          Apartment    1
# 2            3      Rajasthan  Jodhpur  Locality_253          Apartment    1
# 3            4    West Bengal  Kolkata  Locality_241          Apartment    3
# 4            5    West Bengal  Kolkata   Locality_12  Independent House    5
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          2538          457.17          0.1801        1993  ...
# 1           654           35.25          0.0539        2009  ...
# 2           947           44.88          0.0474        2002  ...
# 3          2072          174.43          0.0842        2014  ...
# 4          2331          197.42          0.0847        2010  ...
#
#   Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 0              32               6                 2
# ...

# %%
df.sample(5)
# Out:
#         Property_ID        State       City      Locality      Property_Type  \
# 158211       158212    Telangana  Hyderabad  Locality_432          Apartment
# 85504         85505       Punjab   Ludhiana   Locality_64          Apartment
# 42810         42811   Tamil Nadu    Chennai  Locality_290  Independent House
# 227599       227600       Kerala      Kochi  Locality_265          Apartment
# 85391         85392  West Bengal    Kolkata  Locality_123          Apartment
#
#         BHK  Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 158211    5          2921          304.78          0.1043        2002  ...
# 85504     5          3057          154.06          0.0504        2010  ...
# 42810     3          2215          253.40          0.1144        2024  ...
# 227599    1          1031           83.43          0.0809        2003  ...
# 85391     4          2708          205.25          0.0758        1999  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Property_ID', 'State', 'City', 'Locality', 'Property_Type', 'BHK',
#        'Size_in_SqFt', 'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built',
#        'Furnished_Status', 'Floor_No', 'Total_Floors', 'Age_of_Property',
#        'Nearby_Schools', 'Nearby_Hospitals', 'Public_Transport_Accessibility',
#        'Parking_Space', 'Security', 'Amenities', 'Facing', 'Owner_Type',
#        'Availability_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Property_ID                     250000 non-null  int64
#  1   State                           250000 non-null  object
#  2   City                            250000 non-null  object
#  3   Locality                        250000 non-null  object
#  4   Property_Type                   250000 non-null  object
#  5   BHK                             250000 non-null  int64
#  6   Size_in_SqFt                    250000 non-null  int64
#  7   Price_in_Lakhs                  250000 non-null  float64
#  8   Price_per_SqFt                  250000 non-null  float64
#  9   Year_Built                      250000 non-null  int64
#  10  Furnished_Status                250000 non-null  object
#  11  Floor_No                        250000 non-null  int64
# ...

# %% [markdown]
# The `Amenities` column contains 'nan' values that need to be filled with 'None', as some properties do not have any amenities.

# %%
df.State.unique()
# Out:
# array(['Delhi', 'Uttar Pradesh', 'Rajasthan', 'West Bengal', 'Punjab',
#        'Maharashtra', 'Gujarat', 'Madhya Pradesh', 'Tamil Nadu',
#        'Karnataka', 'Kerala', 'Telangana'], dtype=object)

# %%
df.City.unique()
# Out:
# array(['Delhi', 'Lucknow', 'Jodhpur', 'Kolkata', 'Chandigarh', 'Ludhiana',
#        'Pune', 'Ahmedabad', 'Indore', 'Chennai', 'Bengaluru', 'Kochi',
#        'Jaipur', 'Mumbai', 'Hyderabad'], dtype=object)

# %% [raw]
# city always belongs to exactly the same state

# %%
df.Locality.unique() # high cardinality in this columns ->remove it
# Out:
# array(['Locality_130', 'Locality_245', 'Locality_253', 'Locality_241',
#        'Locality_12', 'Locality_408', 'Locality_64', 'Locality_49',
#        'Locality_471', 'Locality_214', 'Locality_482', 'Locality_76',
#        'Locality_421', 'Locality_339', 'Locality_350', 'Locality_104',
#        'Locality_364', 'Locality_140', 'Locality_156', 'Locality_473',
#        'Locality_347', 'Locality_344', 'Locality_150', 'Locality_469',
#        'Locality_430', 'Locality_497', 'Locality_462', 'Locality_481',
#        'Locality_311', 'Locality_255', 'Locality_479', 'Locality_70',
#        'Locality_424', 'Locality_475', 'Locality_483', 'Locality_199',
#        'Locality_41', 'Locality_60', 'Locality_286', 'Locality_368',
#        'Locality_232', 'Locality_273', 'Locality_211', 'Locality_215',
#        'Locality_301', 'Locality_201', 'Locality_111', 'Locality_162',
#        'Locality_319', 'Locality_412', 'Locality_20', 'Locality_284',
# ...

# %%
df.Property_Type.unique()
# Out:
# array(['Apartment', 'Independent House', 'Villa'], dtype=object)

# %%
df.BHK.unique() # max bhk
# Out:
# array([4, 1, 3, 5, 2], dtype=int64)
